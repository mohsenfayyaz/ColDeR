# %%
# MOHSEN
import os
from dotenv import load_dotenv
from huggingface_hub import login

load_dotenv()
login(os.environ["HF_TOKEN"])
print("CUDA_VISIBLE_DEVICES:", os.environ["CUDA_VISIBLE_DEVICES"], "HF_HOME:", os.environ["HF_HOME"])
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /home/mohsenfayyaz/.cache/huggingface/token
# Login successful
# CUDA_VISIBLE_DEVICES: 0 HF_HOME: /local1/mohsenfayyaz/.hfcache/

# %%
import torch
import numpy as np
import pandas as pd
from tqdm.auto import tqdm
import matplotlib.pyplot as plt
import matplotlib
from IPython.display import display, HTML
import transformers
from transformers import AutoTokenizer, AutoConfig

from DecompX.src.decompx_utils import DecompXConfig
from DecompX.src.modeling_bert import BertForSequenceClassification, BertModel
from DecompX.src.modeling_roberta import RobertaForSequenceClassification, RobertaModel

pd.set_option('display.max_columns', None)

### NQ
# df_raw = pd.read_pickle("hf://datasets/Retriever-Contextualization/datasets/nq/facebook--contriever-msmarco_corpus2681468.pkl")
### RE_DOCRED
df_raw = pd.read_pickle("hf://datasets/Retriever-Contextualization/datasets/re-docred/facebook--contriever-msmarco_corpus105925.pkl")
attrs = df_raw.attrs.copy()
df_raw = df_raw.merge(pd.read_pickle("hf://datasets/Retriever-Contextualization/datasets/Re-DocRED/queries_test_validation.pkl"), left_on="query_id", right_on="id")
df_raw.attrs = attrs

# df_raw.style.set_properties(**{'background-color': 'black', 'color': 'lawngreen'})
attrs
# Out:
# {'model': 'facebook/contriever-msmarco',
#  'query_model': 'facebook/contriever-msmarco',
#  'context_model': 'facebook/contriever-msmarco',
#  'pooling': 'avg',
#  'dataset': 're-docred',
#  'corpus_size': 105925,
#  'eval': {'ndcg': {'NDCG@1': 0.46109,
#    'NDCG@3': 0.49878,
#    'NDCG@5': 0.50989,
#    'NDCG@10': 0.5215,
#    'NDCG@100': 0.54809,
#    'NDCG@1000': 0.56627},
#   'map': {'MAP@1': 0.46109,
#    'MAP@3': 0.48954,
#    'MAP@5': 0.49568,
#    'MAP@10': 0.50046,
#    'MAP@100': 0.50531,
#    'MAP@1000': 0.50593},
#   'recall': {'Recall@1': 0.46109,
#    'Recall@3': 0.52552,
#    'Recall@5': 0.55258,
#    'Recall@10': 0.58856,
#    'Recall@100': 0.72008,
#    'Recall@1000': 0.86709},
#   'precision': {'P@1': 0.46109,
#    'P@3': 0.17517,
#    'P@5': 0.11052,
#    'P@10': 0.05886,
#    'P@100': 0.0072,
#    'P@1000': 0.00087}}}

# %%
### df filtering
import plotly.express as px

def find_index(l, idx, not_found_value=np.inf):
    try:
        return l.index(idx)
    except:
        return not_found_value

### FILTER MULTI GOLD DOCS
print("Total:", len(df_raw))
df = df_raw.loc[df_raw["gold_docs"].str.len() == 1, :].copy()
print("Total:", len(df))
# df.drop_duplicates(subset=["query"], keep="first", inplace=True)
# print("Total:", len(df))

### COMPUTE HIT RANK
df["hit_rank"] = df.apply(lambda row: min([find_index(list(row["scores_1000"].keys()), doc_id) + 1 for doc_id in row["gold_docs"]]), axis=1)
# df["hit_rank"].hist(figsize=(8, 4), bins=50)

dfc = df.copy(); dfc["hit_rank"] = dfc["hit_rank"].astype(str);
fig = px.sunburst(dfc, path=[px.Constant("all"), 'hit_rank'], width=250, height=250)
fig.update_traces(textinfo='label+percent entry+value')
fig.update_layout(margin={'t':0,'l':0,'b':0,'r':0})
fig.show("svg")

### Prepare Docs (title+text)
df["gold_doc"] = df["gold_docs_text"].apply(lambda x: list(x.items())[0][1])
# df["gold_doc"] = df["gold_doc"].apply(lambda x: x["title"] + " " + x["text"])
df["gold_doc"] = df["gold_doc"].apply(lambda x: x["text"])
df["gold_doc_score"] = df["scores_gold"].apply(lambda x: list(x.items())[0][1])
df["pred_doc"] = df["predicted_docs_text_10"].apply(lambda x: list(x.items())[0][1])
# df["pred_doc"] = df["pred_doc"].apply(lambda x: x["title"] + " " + x["text"])
df["pred_doc"] = df["pred_doc"].apply(lambda x: x["text"])
df["pred_doc_score"] = df["scores_1000"].apply(lambda x: list(x.items())[0][1])

df["gold_doc_len"] = df["gold_doc"].str.split().apply(len)
df["pred_doc_len"] = df["pred_doc"].str.split().apply(len)


df.sort_values("hit_rank")
# Out:
# Total: 7170
# Total: 7170
#              query_id                                              query  \
# 7150  validation16256                          Where was Will Weng born?
# 7151  validation16257                      Where was Will Weng educated?
# 7152  validation16258                      Where was Will Weng educated?
# 7153  validation16259               What conflict was Will Weng part of?
# 29            test139           Who produced Long Hard Road Out of Hell?
# ...               ...                                                ...
# 45            test204  Which country is West Saint Joseph Street asso...
# 4670   validation4684  Which administrative territorial entity is MAP...
# 4673   validation4712  Which administrative territorial entity is Sky...
# 2               test2  Which administrative territorial entity is The...
# 4              test10  Which administrative territorial entity is The...
#
#                          gold_docs  \
# 7150                   [Will Weng]
# 7151                   [Will Weng]
# 7152                   [Will Weng]
# 7153                   [Will Weng]
# 29    [Long Hard Road Out of Hell]
# ...                            ...
# 45                          [WHTV]
# 4670     [Christine Razanamahasoa]
# 4673         [Wayne Gretzky Drive]
# 2                      [Loud Tour]
# 4                      [Loud Tour]
#
#                                          gold_docs_text  \
# 7150  {'Will Weng': {'text': 'Will Weng ( February 2...
# 7151  {'Will Weng': {'text': 'Will Weng ( February 2...
# 7152  {'Will Weng': {'text': 'Will Weng ( February 2...
# 7153  {'Will Weng': {'text': 'Will Weng ( February 2...
# 29    {'Long Hard Road Out of Hell': {'text': '" Lon...
# ...                                                 ...
# 45    {'WHTV': {'text': 'WHTV was a television stati...
# 4670  {'Christine Razanamahasoa': {'text': 'Christin...
# 4673  {'Wayne Gretzky Drive': {'text': 'Wayne Gretzk...
# 2     {'Loud Tour': {'text': 'The Loud Tour was the ...
# 4     {'Loud Tour': {'text': 'The Loud Tour was the ...
#
#                                            scores_stats  \
# 7150  {'len': 1000, 'max': 1.6899311542510986, 'min'...
# 7151  {'len': 1000, 'max': 1.5464872121810913, 'min'...
# 7152  {'len': 1000, 'max': 1.5464872121810913, 'min'...
# 7153  {'len': 1000, 'max': 1.414757251739502, 'min':...
# 29    {'len': 1000, 'max': 1.905516266822815, 'min':...
# ...                                                 ...
# 45    {'len': 1000, 'max': 1.3445934057235718, 'min'...
# 4670  {'len': 1000, 'max': 1.3073686361312866, 'min'...
# 4673  {'len': 1000, 'max': 1.196344017982483, 'min':...
# 2     {'len': 1000, 'max': 1.2572499513626099, 'min'...
# 4     {'len': 1000, 'max': 1.2572499513626099, 'min'...
#
#                                             scores_gold  \
# 7150                  {'Will Weng': 1.6899311542510986}
# 7151                  {'Will Weng': 1.5464872121810913}
# 7152                  {'Will Weng': 1.5464872121810913}
# 7153                   {'Will Weng': 1.414757251739502}
# 29    {'Long Hard Road Out of Hell': 1.905516266822815}
# ...                                                 ...
# 45                                       {'WHTV': None}
# 4670                  {'Christine Razanamahasoa': None}
# 4673                      {'Wayne Gretzky Drive': None}
# 2                                   {'Loud Tour': None}
# 4                                   {'Loud Tour': None}
#
#                                             scores_1000  \
# 7150  {'Will Weng': 1.6899311542510986, 'Weng Shilie...
# 7151  {'Will Weng': 1.5464872121810913, 'Weng Shilie...
# 7152  {'Will Weng': 1.5464872121810913, 'Weng Shilie...
# 7153  {'Will Weng': 1.414757251739502, 'Wen Tianxian...
# 29    {'Long Hard Road Out of Hell': 1.9055162668228...
# ...                                                 ...
# 45    {'Saint Joseph's Oratory': 1.3445934057235718,...
# 4670  {'Autonomous Region in Muslim Mindanao': 1.307...
# 4673  {'Sky Zone': 1.196344017982483, 'Longreach, Qu...
# 2     {'Palasport Olimpico and Stadio Comunale area ...
# 4     {'Palasport Olimpico and Stadio Comunale area ...
#
#                                  predicted_docs_text_10               id  \
# 7150  {'Will Weng': {'text': 'Will Weng ( February 2...  validation16256
# 7151  {'Will Weng': {'text': 'Will Weng ( February 2...  validation16257
# 7152  {'Will Weng': {'text': 'Will Weng ( February 2...  validation16258
# 7153  {'Will Weng': {'text': 'Will Weng ( February 2...  validation16259
# 29    {'Long Hard Road Out of Hell': {'text': '" Lon...          test139
# ...                                                 ...              ...
# 45    {'Saint Joseph's Oratory': {'text': 'Saint Jos...          test204
# 4670  {'Autonomous Region in Muslim Mindanao': {'tex...   validation4684
# 4673  {'Sky Zone': {'text': 'Sky Zone is a chain of ...   validation4712
# 2     {'Palasport Olimpico and Stadio Comunale area ...            test2
# 4     {'Palasport Olimpico and Stadio Comunale area ...           test10
#
#                            title  \
# 7150                   Will Weng
# 7151                   Will Weng
# 7152                   Will Weng
# 7153                   Will Weng
# 29    Long Hard Road Out of Hell
# ...                          ...
# 45                          WHTV
# 4670     Christine Razanamahasoa
# 4673         Wayne Gretzky Drive
# 2                      Loud Tour
# 4                      Loud Tour
#
#                                               vertexSet  \
# 7150  [[{'name': 'Will Weng', 'pos': [0, 2], 'sent_i...
# 7151  [[{'name': 'Will Weng', 'pos': [0, 2], 'sent_i...
# 7152  [[{'name': 'Will Weng', 'pos': [0, 2], 'sent_i...
# 7153  [[{'name': 'Will Weng', 'pos': [0, 2], 'sent_i...
# 29    [[{'name': 'Long Hard Road Out of Hell', 'pos'...
# ...                                                 ...
# 45    [[{'name': 'WHTV', 'pos': [6, 7], 'sent_id': 2...
# 4670  [[{'type': 'PER', 'pos': [0, 3], 'name': 'Chri...
# 4673  [[{'type': 'LOC', 'pos': [0, 3], 'name': 'Wayn...
# 2     [[{'name': 'Loud', 'pos': [23, 24], 'sent_id':...
# 4     [[{'name': 'Loud', 'pos': [23, 24], 'sent_id':...
#
#                                                  labels  \
# 7150  [{'r': 'P19', 'h': 0, 't': 7, 'evidence': [0, ...
# 7151  [{'r': 'P19', 'h': 0, 't': 7, 'evidence': [0, ...
# 7152  [{'r': 'P19', 'h': 0, 't': 7, 'evidence': [0, ...
# 7153  [{'r': 'P19', 'h': 0, 't': 7, 'evidence': [0, ...
# 29    [{'r': 'P162', 'h': 0, 't': 7, 'evidence': [0,...
# ...                                                 ...
# 45    [{'r': 'P131', 'h': 2, 't': 3, 'evidence': [0]...
# 4670  [{'r': 'P27', 'h': 0, 't': 1, 'evidence': [0]}...
# 4673  [{'r': 'P54', 'h': 7, 't': 8, 'evidence': [1]}...
# 2     [{'r': 'P577', 'h': 0, 't': 6, 'evidence': [1]...
# 4     [{'r': 'P577', 'h': 0, 't': 6, 'evidence': [1]...
#
#                                                   sents       split  \
# 7150  [[Will, Weng, (, February, 25, ,, 1907, –, May...  validation
# 7151  [[Will, Weng, (, February, 25, ,, 1907, –, May...  validation
# 7152  [[Will, Weng, (, February, 25, ,, 1907, –, May...  validation
# 7153  [[Will, Weng, (, February, 25, ,, 1907, –, May...  validation
# 29    [[", Long, Hard, Road, Out, of, Hell, ", is, a...        test
# ...                                                 ...         ...
# 45    [[WHTV, was, a, television, station, licensed,...        test
# 4670  [[Christine, Harijaona, Razanamahasoa, is, a, ...  validation
# 4673  [[Wayne, Gretzky, Drive, is, a, freeway, in, E...  validation
# 2     [[The, Loud, Tour, was, the, fourth, overall, ...        test
# 4     [[The, Loud, Tour, was, the, fourth, overall, ...        test
#
#                                                   label  label_idx  \
# 7150   {'r': 'P19', 'h': 0, 't': 7, 'evidence': [0, 1]}          0
# 7151   {'r': 'P69', 'h': 0, 't': 9, 'evidence': [0, 1]}          1
# 7152  {'r': 'P69', 'h': 0, 't': 12, 'evidence': [0, 3]}          2
# 7153  {'r': 'P607', 'h': 0, 't': 16, 'evidence': [0,...          3
# 29    {'r': 'P162', 'h': 0, 't': 7, 'evidence': [0, ...          0
# ...                                                 ...        ...
# 45    {'r': 'P17', 'h': 15, 't': 3, 'evidence': [0, 2]}         14
# 4670  {'h': 18, 't': 1, 'r': 'P131', 'evidence': [0,...         33
# 4673  {'r': 'P131', 'h': 9, 't': 2, 'evidence': [0, 2]}          6
# 2       {'r': 'P131', 'h': 10, 't': 8, 'evidence': [4]}          2
# 4     {'h': 10, 't': 7, 'r': 'P131', 'evidence': [3,...         10
#
#                                             head_entity  \
# 7150  [{'name': 'Will Weng', 'pos': [0, 2], 'sent_id...
# 7151  [{'name': 'Will Weng', 'pos': [0, 2], 'sent_id...
# 7152  [{'name': 'Will Weng', 'pos': [0, 2], 'sent_id...
# 7153  [{'name': 'Will Weng', 'pos': [0, 2], 'sent_id...
# 29    [{'name': 'Long Hard Road Out of Hell', 'pos':...
# ...                                                 ...
# 45    [{'type': 'LOC', 'pos': [10, 14], 'name': 'Wes...
# 4670  [{'type': 'ORG', 'pos': [15, 16], 'name': 'MAP...
# 4673  [{'name': 'Skyreach Centre', 'pos': [14, 16], ...
# 2     [{'sent_id': 4, 'type': 'LOC', 'pos': [11, 14]...
# 4     [{'sent_id': 4, 'type': 'LOC', 'pos': [11, 14]...
#
#                                             tail_entity  \
# 7150  [{'name': 'Terre Haute', 'pos': [2, 4], 'sent_...
# 7151  [{'name': 'Indiana State Teachers College', 'p...
# 7152  [{'name': 'Columbia University School of Journ...
# 7153  [{'name': 'World War II', 'pos': [12, 15], 'se...
# 29    [{'name': 'Marilyn Manson', 'pos': [19, 21], '...
# ...                                                 ...
# 45    [{'name': 'United States', 'pos': [11, 13], 's...
# 4670  [{'name': 'Malagasy', 'pos': [5, 6], 'sent_id'...
# 4673  [{'name': 'Alberta', 'pos': [9, 10], 'sent_id'...
# 2     [{'name': 'London', 'pos': [1, 2], 'sent_id': ...
# 4     [{'name': 'United Kingdom', 'pos': [18, 20], '...
#
#                  head_entity_names  \
# 7150             {Weng, Will Weng}
# 7151             {Weng, Will Weng}
# 7152             {Weng, Will Weng}
# 7153             {Weng, Will Weng}
# 29    {Long Hard Road Out of Hell}
# ...                            ...
# 45      {West Saint Joseph Street}
# 4670                       {MAPAR}
# 4673             {Skyreach Centre}
# 2                   {The O2 Arena}
# 4                   {The O2 Arena}
#
#                                tail_entity_names    head_entity_longest_name  \
# 7150                               {Terre Haute}                   Will Weng
# 7151            {Indiana State Teachers College}                   Will Weng
# 7152  {Columbia University School of Journalism}                   Will Weng
# 7153                              {World War II}                   Will Weng
# 29                      {Manson, Marilyn Manson}  Long Hard Road Out of Hell
# ...                                          ...                         ...
# 45                               {United States}    West Saint Joseph Street
# 4670                      {Madagascar, Malagasy}                       MAPAR
# 4673                                   {Alberta}             Skyreach Centre
# 2                                       {London}                The O2 Arena
# 4                               {United Kingdom}                The O2 Arena
#
#                       tail_entity_longest_name head_entity_types  \
# 7150                               Terre Haute             {PER}
# 7151            Indiana State Teachers College             {PER}
# 7152  Columbia University School of Journalism             {PER}
# 7153                              World War II             {PER}
# 29                              Marilyn Manson            {MISC}
# ...                                        ...               ...
# 45                               United States             {LOC}
# 4670                                Madagascar             {ORG}
# 4673                                   Alberta             {LOC}
# 2                                       London             {LOC}
# 4                               United Kingdom             {LOC}
#
#      tail_entity_types evidence_sent_ids  \
# 7150             {LOC}            [0, 1]
# 7151             {ORG}            [0, 1]
# 7152             {ORG}            [0, 3]
# 7153            {MISC}            [0, 4]
# 29               {PER}         [0, 1, 5]
# ...                ...               ...
# 45               {LOC}            [0, 2]
# 4670             {LOC}        [0, 9, 12]
# 4673             {LOC}            [0, 2]
# 2                {LOC}               [4]
# 4                {LOC}            [3, 4]
#
#                                          evidence_sents  \
# 7150  [[Will, Weng, (, February, 25, ,, 1907, –, May...
# 7151  [[Will, Weng, (, February, 25, ,, 1907, –, May...
# 7152  [[Will, Weng, (, February, 25, ,, 1907, –, May...
# 7153  [[Will, Weng, (, February, 25, ,, 1907, –, May...
# 29    [[", Long, Hard, Road, Out, of, Hell, ", is, a...
# ...                                                 ...
# 45    [[WHTV, was, a, television, station, licensed,...
# 4670  [[Christine, Harijaona, Razanamahasoa, is, a, ...
# 4673  [[Wayne, Gretzky, Drive, is, a, freeway, in, E...
# 2     [[In, London, ,, Rihanna, played, a, record, b...
# 4     [[The, Loud, Tour, was, a, large, commercial, ...
#
#                                 head_entity_in_evidence  \
# 7150  [{'name': 'Will Weng', 'pos': [0, 2], 'sent_id...
# 7151  [{'name': 'Will Weng', 'pos': [0, 2], 'sent_id...
# 7152  [{'name': 'Will Weng', 'pos': [0, 2], 'sent_id...
# 7153  [{'name': 'Will Weng', 'pos': [0, 2], 'sent_id...
# 29    [{'name': 'Long Hard Road Out of Hell', 'pos':...
# ...                                                 ...
# 45    [{'type': 'LOC', 'pos': [10, 14], 'name': 'Wes...
# 4670  [{'type': 'ORG', 'pos': [15, 16], 'name': 'MAP...
# 4673  [{'name': 'Skyreach Centre', 'pos': [14, 16], ...
# 2     [{'sent_id': 4, 'type': 'LOC', 'pos': [11, 14]...
# 4     [{'sent_id': 4, 'type': 'LOC', 'pos': [11, 14]...
#
#                                 tail_entity_in_evidence relation  \
# 7150  [{'name': 'Terre Haute', 'pos': [2, 4], 'sent_...      P19
# 7151  [{'name': 'Indiana State Teachers College', 'p...      P69
# 7152  [{'name': 'Columbia University School of Journ...      P69
# 7153  [{'name': 'World War II', 'pos': [12, 15], 'se...     P607
# 29    [{'name': 'Marilyn Manson', 'pos': [19, 21], '...     P162
# ...                                                 ...      ...
# 45    [{'name': 'United States', 'pos': [11, 13], 's...      P17
# 4670  [{'name': 'Malagasy', 'pos': [5, 6], 'sent_id'...     P131
# 4673  [{'name': 'Alberta', 'pos': [9, 10], 'sent_id'...     P131
# 2     [{'name': 'London', 'pos': [1, 2], 'sent_id': ...     P131
# 4     [{'name': 'United Kingdom', 'pos': [18, 20], '...     P131
#
#                                          relation_name  \
# 7150                                    place of birth
# 7151                                       educated at
# 7152                                       educated at
# 7153                                          conflict
# 29                                            producer
# ...                                                ...
# 45                                             country
# 4670  located in the administrative territorial entity
# 4673  located in the administrative territorial entity
# 2     located in the administrative territorial entity
# 4     located in the administrative territorial entity
#
#                                          query_question  duplicate_titles_len  \
# 7150                          Where was Will Weng born?                     0
# 7151                      Where was Will Weng educated?                     0
# 7152                      Where was Will Weng educated?                     0
# 7153               What conflict was Will Weng part of?                     0
# 29             Who produced Long Hard Road Out of Hell?                     0
# ...                                                 ...                   ...
# 45    Which country is West Saint Joseph Street asso...                     0
# 4670  Which administrative territorial entity is MAP...                     0
# 4673  Which administrative territorial entity is Sky...                     0
# 2     Which administrative territorial entity is The...                     0
# 4     Which administrative territorial entity is The...                     0
#
#      duplicate_titles  hit_rank  \
# 7150               {}       1.0
# 7151               {}       1.0
# 7152               {}       1.0
# 7153               {}       1.0
# 29                 {}       1.0
# ...               ...       ...
# 45                 {}       inf
# 4670               {}       inf
# 4673               {}       inf
# 2                  {}       inf
# 4                  {}       inf
#
#                                                gold_doc  gold_doc_score  \
# 7150  Will Weng ( February 25 , 1907 – May 2 , 1993 ...        1.689931
# 7151  Will Weng ( February 25 , 1907 – May 2 , 1993 ...        1.546487
# 7152  Will Weng ( February 25 , 1907 – May 2 , 1993 ...        1.546487
# 7153  Will Weng ( February 25 , 1907 – May 2 , 1993 ...        1.414757
# 29    " Long Hard Road Out of Hell " is a song by Am...        1.905516
# ...                                                 ...             ...
# 45    WHTV was a television station licensed to Jack...             NaN
# 4670  Christine Harijaona Razanamahasoa is a Malagas...             NaN
# 4673  Wayne Gretzky Drive is a freeway in Edmonton ,...             NaN
# 2     The Loud Tour was the fourth overall and third...             NaN
# 4     The Loud Tour was the fourth overall and third...             NaN
#
#                                                pred_doc  pred_doc_score  \
# 7150  Will Weng ( February 25 , 1907 – May 2 , 1993 ...        1.689931
# 7151  Will Weng ( February 25 , 1907 – May 2 , 1993 ...        1.546487
# 7152  Will Weng ( February 25 , 1907 – May 2 , 1993 ...        1.546487
# 7153  Will Weng ( February 25 , 1907 – May 2 , 1993 ...        1.414757
# 29    " Long Hard Road Out of Hell " is a song by Am...        1.905516
# ...                                                 ...             ...
# 45    Saint Joseph 's Oratory of Mount Royal ( ) is ...        1.344593
# 4670  The Autonomous Region in Muslim Mindanao ( , A...        1.307369
# 4673  Sky Zone is a chain of indoor family entertain...        1.196344
# 2     The facilities that were used for the 2006 Win...        1.257250
# 4     The facilities that were used for the 2006 Win...        1.257250
#
#       gold_doc_len  pred_doc_len
# 7150           161           161
# 7151           161           161
# 7152           161           161
# 7153           161           161
# 29             318           318
# ...            ...           ...
# 45             145           149
# 4670           242           244
# 4673           166           190
# 2              140           201
# 4              140           201
#
# [7170 rows x 40 columns]

# %%
DATASET = df.attrs["dataset"]
MODEL = df.attrs["model"]  # 'facebook/contriever-msmarco'  # Only BERT or RoBERTa
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
CONFIGS = {
    "DecompX":
        DecompXConfig(
            include_biases=True,
            bias_decomp_type="absdot",
            include_LN1=True,
            include_FFN=True,
            FFN_approx_type="GeLU_ZO",
            include_LN2=True,
            aggregation="vector",
            include_classifier_w_pooler=True,
            tanh_approx_type="ZO",
            output_all_layers=True,
            output_attention=None,
            output_res1=None,
            output_LN1=None,
            output_FFN=None,
            output_res2=None,
            output_encoder=None,
            output_aggregated="vector",  # Changed
            output_pooler="norm",
            output_classifier=True,
        ),
}

def load_model_tokenizer(model_name):
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model_config = AutoConfig.from_pretrained(model_name)
    if type(model_config) is transformers.models.roberta.configuration_roberta.RobertaConfig:
        model = RobertaModel.from_pretrained(model_name)
    elif type(model_config) is transformers.models.bert.configuration_bert.BertConfig:
        model = BertModel.from_pretrained(model_name)
    else:
        raise Exception(f"Not implemented model: {model_name}")
    model.to(DEVICE)
    return model, tokenizer

model, tokenizer = load_model_tokenizer(MODEL)
# Out:
# /data2/mohsenfayyaz/anaconda3/envs/mohsen-env/lib/python3.12/site-packages/transformers/tokenization_utils_base.py:1617: FutureWarning:
#
# `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884

# %%
from IPython.display import display, HTML
import matplotlib.pyplot as plt
import matplotlib

def print_importance(importance, tokenized_text, discrete=False, prefix=""):
    """
    importance: (sent_len)
    """
    assert len(importance) == len(tokenized_text)
    importance = importance / np.abs(importance).max() / 1.0  # Normalize
    if discrete:
        importance = np.argsort(np.argsort(importance)) / len(importance) / 1.6

    html = "<pre style='line-height: 28px; display: flex; flex-flow: row wrap;'>"+prefix
    for i in range(len(tokenized_text)):
        # if importance[i] > 0:
        #     rgba = plt.get_cmap('Reds')(importance[i] * .7)   # Wistia
        # else:
        #     rgba = plt.get_cmap('Greens')(np.abs(importance[i]) + .5)   # Wistia
        rgba = plt.get_cmap('coolwarm')((importance[i] + 1) / 2)
        text_color = "color: rgba(255, 255, 255, 1.0); " if np.abs(importance[i]) > 1 else "color: rgba(10, 10, 10, 1.0); "
        color = f"background-color: rgba({rgba[0]*255}, {rgba[1]*255}, {rgba[2]*255}, {rgba[3]}); " + text_color
        html += (f"<div style='"
                 f"{color}"
                 f"border-radius: 5px; padding: 2px; margin: 1px;"
                 f"font-weight: {int(800)};"
                 "width: fit-content; display: flex;"
                 "'>")
        html += tokenized_text[i].replace('<', "[").replace(">", "]")
        html += "</div> "
        if tokenized_text[i] in ["hypothesis,", "hold.", '"contradiction"']:
            html += '<br>'
    return html

def html_wrapper(htmls, desc="text", legend="?"):
    html = ""
    head = """
    <head>
    <style>
        @media print {
            -webkit-print-color-adjust: exact;
        }
        fieldset {
            max-width: 1000px; padding: 8px; border-radius: 20px; border: 3px solid rgb(15, 200, 200); background: white; color: black;
        }
        legend {
            margin-left: 10px; padding: 7px; padding-left: 20px; padding-right: 20px; border: 2px solid rgb(15, 200, 200);
            border-radius: 20px; background: white;
            /*font-family: Arial !important;*/
            font-weight: 600;
        }
        table tr td {
            white-space: nowrap; padding: 5px;
        }
    </style>
    </head>
    """
    html += head
    html += f"""
        <fieldset>
            <legend>{legend}</legend>
            <table style='width: 1000px; font-weight: 600; color: black;'>
            """
    for i in range(len(htmls)):
        html += """
        <tr>
        """
        html += f"<td style='text-align: center; width: 100px;'>{desc}:</td><td>"
        html += htmls[i]
        html += "</td></tr>"
    html += "</table></fieldset>"
    return html

# %%
def run_decompx(text):
    inputs = tokenizer([text], padding=True, truncation=True, return_tensors='pt')
    input_ids = inputs["input_ids"]
    inputs.to(model.device)
    with torch.no_grad():
        last_hidden_states, pooler_output, hidden_states, decompx_last_layer_outputs, decompx_all_layers_outputs = model(
            **inputs,
            output_attentions=False,
            return_dict=False,
            output_hidden_states=True,
            decompx_config=CONFIGS["DecompX"]
        )
        ### decompx_last_layer_outputs.aggregated ~ 1 * [1, 70, 70, 768] ~ layer * [batch, seq, seq, emb_dim] ###
        ### last_hidden_states ~ [1, 70, 768] ~ [batch, seq_len, emb_dim]
        print(last_hidden_states.shape)  # 
        mean_pooled = last_hidden_states[0].mean(dim=0)
        decompx_last_layer_mean = decompx_last_layer_outputs.aggregated[0][0].mean(dim=(0))  # Mean over DecompX similar to the retriever [seq_len, emb_dim]
        tokens_dot_scores = torch.einsum("ij,j->i", decompx_last_layer_mean, mean_pooled)  # [seq_len]
        ranking = torch.argsort(tokens_dot_scores, descending=True).cpu().numpy()
    return {
        "tokens": tokenizer.convert_ids_to_tokens(input_ids[0]),  # [seq_len]
        "tokens_dot_scores": tokens_dot_scores.cpu(),  # [seq_len]  (Dot score with mean)
        "decompx_last_layer_outputs": decompx_last_layer_outputs,  # .aggregated ~ 1 * [1, 70, 70, 768] ~ layer * [batch, seq, seq, emb_dim]
        "decompx_last_layer_mean": decompx_last_layer_mean.cpu(),  # [seq_len, emb_dim]
    }

def plot_demo(idx, heatmap_max_len=-1):
    ### RUN DECOMPX ON QUERY AND DOC
    query = run_decompx(df.loc[idx]["query"])
    gold_doc = run_decompx(df.loc[idx]["gold_doc"])
    pred_doc = run_decompx(df.loc[idx]["pred_doc"])
    head_entity = df.loc[idx]['head_entity_longest_name'] if 'head_entity_longest_name' in df.columns else '?'
    tail_entity = df.loc[idx]['tail_entity_longest_name'] if 'tail_entity_longest_name' in df.columns else '?'
    relation = df.loc[idx]['relation_name'] if 'relation_name' in df.columns else '?'
    split = df.loc[idx]['split'] if 'split' in df.columns else '?'
    
    ### PLOT MEAN DOT IMPORTANCE
    htmls = [print_importance(query["tokens_dot_scores"], query["tokens"])]
    final_html = html_wrapper(htmls, "Query", f"{DATASET}, {MODEL}, idx={idx}, (head={head_entity}, relation={relation}, tail={tail_entity})")
    display(HTML(final_html))
    htmls = [print_importance(gold_doc["tokens_dot_scores"], gold_doc["tokens"])]
    final_html = html_wrapper(htmls, "Gold Doc", f"{DATASET}, {MODEL}, idx={idx}, score={df.loc[idx]['gold_doc_score']}, hit_rank={df.loc[idx]['hit_rank']}")
    display(HTML(final_html))
    htmls = [print_importance(pred_doc["tokens_dot_scores"], pred_doc["tokens"])]
    final_html = html_wrapper(htmls, "Pred Doc", f"{DATASET}, {MODEL}, idx={idx}, score={df.loc[idx]['pred_doc_score']}")
    display(HTML(final_html))
    
    ### PLOT CROSS DOT IMPORTANCE
    from seaborn import heatmap
    import matplotlib.pyplot as plt
    
    def plot_qd_heatmap(query_tokens, query_decomposed, doc_tokens, doc_decomposed, xlabel="Doc", ylabel="Query"):
        with torch.no_grad():
            qd_scores = torch.einsum("id,jd->ij", query_decomposed, doc_decomposed).cpu().numpy()
        # Apply max_len
        if heatmap_max_len > 0:
            qd_scores = qd_scores[:heatmap_max_len, :heatmap_max_len]
            query_tokens = query_tokens[:heatmap_max_len]
            doc_tokens = doc_tokens[:heatmap_max_len]
        plt.figure(figsize=(13, 3.5))  # 30 for debug 15 for aesthetics
        heatmap(qd_scores, cmap=plt.get_cmap('coolwarm'), vmin=-np.max(np.abs(qd_scores)), vmax=np.max(np.abs(qd_scores)), linewidths=0.5, linecolor=(12/255, 12/255, 12/255, 0.1))
        plt.xticks(np.arange(len(doc_tokens))+0.5, doc_tokens, rotation='vertical')
        plt.yticks(np.arange(len(query_tokens))+0.5, query_tokens, rotation='horizontal')
        # plt.grid("on", linewidth=0.2); 
        plt.xlabel(xlabel); plt.ylabel(ylabel)
        plt.tight_layout()
        plt.savefig(f"figs/decompx_heatmap_{idx}.png", dpi=200)
        plt.savefig(f"figs/decompx_heatmap_{idx}.pdf")
        plt.show()
    
    plot_qd_heatmap(query["tokens"], query["decompx_last_layer_mean"], gold_doc["tokens"], gold_doc["decompx_last_layer_mean"], "Gold Document")
    # plot_qd_heatmap(query["tokens"], query["decompx_last_layer_mean"], pred_doc["tokens"], pred_doc["decompx_last_layer_mean"], "Pred Document")
    
    
    ### PLOT SELF DECOMPX BLOCKS
    from seaborn import heatmap
    import matplotlib.pyplot as plt
    
    def plot_decompx_heatmap(tokens, decompx_last_layer_outputs, label="?"):
        norm_heatmap = decompx_last_layer_outputs.aggregated[0][0].norm(dim=-1).cpu().numpy()
        heatmap(norm_heatmap / np.diag(norm_heatmap).reshape((-1, 1)), cmap=plt.get_cmap('Reds'))
        plt.xticks(np.arange(len(tokens))+0.5, tokens, rotation='vertical')
        plt.yticks(np.arange(len(tokens))+0.5, tokens, rotation='horizontal')
        plt.grid("on", linewidth=0.2); plt.xlabel(label); plt.ylabel(label)
    
    plt.figure(figsize=(11, 3))
    plt.subplot(1, 3, 1); plot_decompx_heatmap(query["tokens"], query["decompx_last_layer_outputs"], "Query")
    plt.subplot(1, 3, 2); plot_decompx_heatmap(gold_doc["tokens"], gold_doc["decompx_last_layer_outputs"], "Gold Document")
    plt.subplot(1, 3, 3); plot_decompx_heatmap(pred_doc["tokens"], pred_doc["decompx_last_layer_outputs"], "Pred Document")
    plt.tight_layout()

plot_demo(idx=864, heatmap_max_len=60)  # 1892
# Out:
# /data2/mohsenfayyaz/anaconda3/envs/mohsen-env/lib/python3.12/site-packages/transformers/modeling_utils.py:1141: FutureWarning:
#
# The `device` argument is deprecated and will be removed in v5 of Transformers.
# torch.Size([1, 9, 768])
# torch.Size([1, 175, 768])
# torch.Size([1, 175, 768])
# /tmp/ipykernel_1755055/2245885384.py:10: DeprecationWarning:
#
# __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#
# /tmp/ipykernel_1755055/2245885384.py:21: DeprecationWarning:
#
# __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#     <head>
#     <style>
#         @media print {
#             -webkit-print-color-adjust: exact;
#         }
#         fieldset {
#             max-width: 1000px; padding: 8px; border-radius: 20px; border: 3px solid rgb(15, 200, 200); background: white; color: black;
#         }
#         legend {
#             margin-left: 10px; padding: 7px; padding-left: 20px; padding-right: 20px; border: 2px solid rgb(15, 200, 200);
#             border-radius: 20px; background: white;
#             /*font-family: Arial !important;*/
#             font-weight: 600;
#         }
#         table tr td {
#             white-space: nowrap; padding: 5px;
#         }
#     </style>
#     </head>
#
#         <fieldset>
#             <legend>re-docred, facebook/contriever-msmarco, idx=864, (head=Affordable Care Act, relation=start time, tail=2010)</legend>
#             <table style='width: 1000px; font-weight: 600; color: black;'>
#
#         <tr>
#         <td style='text-align: center; width: 100px;'>Query:</td><td><pre style='line-height: 28px; display: flex; flex-flow: row wrap;'><div style='background-color: rgba(83.794134066, 112.12651664399999, 221.744751948, 1.0); color: rgba(10, 10, 10, 1.0); border-radius: 5px; padding: 2px; margin: 1px;font-weight: 800;width: fit-content; display: flex;'>[CLS]</div> <div style='background-color: rgba(246.56513677499998, 166.252004514, 135.659264484, 1.0); color: rgba(10, 10, 10, 1.0); border-radius: 5px; padding: 2px; margin: 1px;font-weight: 800;width: fit-content; display: flex;'>when</div> <div style='background-color: rgba(231.912197427, 214.04355234, 204.08449486799998, 1.0); color: rgba(10, 10, 10, 1.0); border-radius: 5px; padding: 2px; margin: 1px;font-weight: 800;width: fit-content; display: flex;'>did</div> <div style='background-color: rgba(179.94665529, 3.9668208, 38.30936706, 1.0); color: rgba(10, 10, 10, 1.0); border-radius: 5px; padding: 2px; margin: 1px;font-weight: 800;width: fit-content; display: flex;'>affordable</div> <div style='background-color: rgba(196.07679883700004, 48.249406216000075, 50.48117525300003, 1.0); color: rgba(10, 10, 10, 1.0); border-radius: 5px; padding: 2px; margin: 1px;font-weight: 800;width: fit-content; display: flex;'>care</div> <div style='background-color: rgba(236.98607026500002, 130.62465136, 102.171549505, 1.0); color: rgba(10, 10, 10, 1.0); border-radius: 5px; padding: 2px; margin: 1px;font-weight: 800;width: fit-content; display: flex;'>act</div> <div style='background-color: rgba(217.35642442699998, 88.355446356, 71.48834951799999, 1.0); color: rgba(10, 10, 10, 1.0); border-radius: 5px; padding: 2px; margin: 1px;font-weight: 800;width: fit-content; display: flex;'>start</div> <div style='background-color: rgba(208.60440581999998, 218.175367774, 233.23259222000002, 1.0); color: rgba(10, 10, 10, 1.0); border-radius: 5px; padding: 2px; margin: 1px;font-weight: 800;width: fit-content; display: flex;'>?</div> <div style='background-color: rgba(215.05633441899997, 219.764011774, 226.95436480700002, 1.0); color: rgba(10, 10, 10, 1.0); border-radius: 5px; padding: 2px; margin: 1px;font-weight: 800;width: fit-content; display: flex;'>[SEP]</div> </td></tr></table></fieldset>
#     <head>
#     <style>
#         @media print {
#             -webkit-print-color-adjust: exact;
#         }
#         fieldset {
#             max-width: 1000px; padding: 8px; border-radius: 20px; border: 3px solid rgb(15, 200, 200); background: white; color: black;
#         }
#         legend {
#             margin-left: 10px; padding: 7px; padding-left: 20px; padding-right: 20px; border: 2px solid rgb(15, 200, 200);
#             border-radius: 20px; background: white;
#             /*font-family: Arial !important;*/
#             font-weight: 600;
#         }
#         table tr td {
#             white-space: nowrap; padding: 5px;
#         }
#     </style>
#     </head>
#
#         <fieldset>
#             <legend>re-docred, facebook/contriever-msmarco, idx=864, score=1.4103505611419678, hit_rank=1.0</legend>
#             <table style='width: 1000px; font-weight: 600; color: black;'>
#
#         <tr>
#         <td style='text-align: center; width: 100px;'>Gold Doc:</td><td><pre style='line-height: 28px; display: flex; flex-flow: row wrap;'><div style='background-color: rgba(122.00787408, 157.22372912, 248.043828335, 1.0); color: rgba(10, 10, 10, 1.0); border-radius: 5px; padding: 2px; margin: 1px;font-weight: 800;width: fit-content; display: flex;'>[CLS]</div> <div style='background-color: rgba(224.303677219, 218.834609294, 215.69018637500002, 1.0); color: rgba(10, 10, 10, 1.0); border-radius: 5px; padding: 2px; margin: 1px;font-weight: 800;width: fit-content; display: flex;'>"</div> <div style='background-color: rgba(246.56513677499998, 166.252004514, 135.659264484, 1.0); color: rgba(10, 10, 10, 1.0); border-radius: 5px; padding: 2px; margin: 1px;font-weight: 800;width: fit-content; display: flex;'>united</div> <div style='background-color: rgba(245.206825223, 158.673007305, 127.89559426200002, 1.0); color: rgba(10, 10, 10, 1.0); border-radius: 5px; padding: 2px; margin: 1px;font-weight: 800;width: fit-content; display: flex;'>states</div> <div style='background-color: rgba(242.569717695, 147.593844345, 117.14899047, 1.0); color: rgba(10, 10, 10, 1.0); border-radius: 5px; padding: 2px; margin: 1px;font-weight: 800;width: fit-content; display: flex;'>health</div> <div style='background-color: rgba(234.161826509, 123.464235406, 96.337450893, 1.0); color: rgba(10, 10, 10, 1.0); border-radius: 5px; padding: 2px; margin: 1px;font-weight: 800;width: fit-content; display: flex;'>care</div> <div style='background-color: rgba(179.94665529, 3.9668208, 38.30936706, 1.0); color: rgba(10, 10, 10, 1.0); border-radius: 5px; padding: 2px; margin: 1px;font-weight: 800;width: fit-content; display: flex;'>reform</div> <div style='background-color: rgba(214.034617907, 219.59754054200002, 228.09590967100002, 1.0); color: rgba(10, 10, 10, 1.0); border-radius: 5px; padding: 2px; margin: 1px;font-weight: 800;width: fit-content; display: flex;'>:</div> <div style='background-color: rgba(246.56513677499998, 166.252004514, 135.659264484, 1.0); color: rgba(10, 10, 10, 1.0); border-radius: 5px; padding: 2px; margin: 1px;font-weight: 800;width: fit-content; display: flex;'>progress</div> <div style='background-color: rgba(216.078050931, 219.930483006, 225.81281994300002, 1.0); color: rgba(10, 10, 10, 1.0); border-radius: 5px; padding: 2px; margin: 1px;font-weight: 800;width: fit-content; display: flex;'>to</div> <div style='background-color: rgba(231.069304179, 214.73322162, 205.568401236, 1.0); color: rgba(10, 10, 10, 1.0); border-radius: 5px; padding: 2px; margin: 1px;font-weight: 800;width: fit-content; display: flex;'>date</div> <div style='background-color: rgba(213.012901395, 219.43106931, 229.237454535, 1.0); color: rgba(10, 10, 10, 1.0); border-radius: 5px; padding: 2px; margin: 1px;font-weight: 800;width: fit-content; display: flex;'>and</div> <div style='background-color: rgba(241.112776222, 203.644463836, 184.391881411, 1.0); color: rgba(10, 10, 10, 1.0); border-radius: 5px; padding: 2px; margin: 1px;font-weight: 800;width: fit-content; display: flex;'>next</div> <div style='background-color: rgba(247.16858509499997, 174.670345506, 145.088708196, 1.0); color: rgba(10, 10, 10, 1.0); border-radius: 5px; padding: 2px; margin: 1px;font-weight: 800;width: fit-content; display: flex;'>steps</div> <div style='background-color: rgba(222.230590371, 219.888891726, 218.53914733500002, 1.0); color: rgba(10, 10, 10, 1.0); border-radius: 5px; padding: 2px; margin: 1px;font-weight: 800;width: fit-content; display: flex;'>"</div> <div style='background-color: rgba(215.05633441899997, 219.764011774, 226.95436480700002, 1.0); color: rgba(10, 10, 10, 1.0); border-radius: 5px; padding: 2px; margin: 1px;font-weight: 800;width: fit-content; display: flex;'>is</div> <div style='background-color: rgba(220.164916979, 220.596367934, 221.246640487, 1.0); color: rgba(10, 10, 10, 1.0); border-radius: 5px; padding: 2px; margin: 1px;font-weight: 800;width: fit-content; dis ...
#     <head>
#     <style>
#         @media print {
#             -webkit-print-color-adjust: exact;
#         }
#         fieldset {
#             max-width: 1000px; padding: 8px; border-radius: 20px; border: 3px solid rgb(15, 200, 200); background: white; color: black;
#         }
#         legend {
#             margin-left: 10px; padding: 7px; padding-left: 20px; padding-right: 20px; border: 2px solid rgb(15, 200, 200);
#             border-radius: 20px; background: white;
#             /*font-family: Arial !important;*/
#             font-weight: 600;
#         }
#         table tr td {
#             white-space: nowrap; padding: 5px;
#         }
#     </style>
#     </head>
#
#         <fieldset>
#             <legend>re-docred, facebook/contriever-msmarco, idx=864, score=1.4103505611419678</legend>
#             <table style='width: 1000px; font-weight: 600; color: black;'>
#
#         <tr>
#         <td style='text-align: center; width: 100px;'>Pred Doc:</td><td><pre style='line-height: 28px; display: flex; flex-flow: row wrap;'><div style='background-color: rgba(122.00787408, 157.22372912, 248.043828335, 1.0); color: rgba(10, 10, 10, 1.0); border-radius: 5px; padding: 2px; margin: 1px;font-weight: 800;width: fit-content; display: flex;'>[CLS]</div> <div style='background-color: rgba(224.303677219, 218.834609294, 215.69018637500002, 1.0); color: rgba(10, 10, 10, 1.0); border-radius: 5px; padding: 2px; margin: 1px;font-weight: 800;width: fit-content; display: flex;'>"</div> <div style='background-color: rgba(246.56513677499998, 166.252004514, 135.659264484, 1.0); color: rgba(10, 10, 10, 1.0); border-radius: 5px; padding: 2px; margin: 1px;font-weight: 800;width: fit-content; display: flex;'>united</div> <div style='background-color: rgba(245.206825223, 158.673007305, 127.89559426200002, 1.0); color: rgba(10, 10, 10, 1.0); border-radius: 5px; padding: 2px; margin: 1px;font-weight: 800;width: fit-content; display: flex;'>states</div> <div style='background-color: rgba(242.569717695, 147.593844345, 117.14899047, 1.0); color: rgba(10, 10, 10, 1.0); border-radius: 5px; padding: 2px; margin: 1px;font-weight: 800;width: fit-content; display: flex;'>health</div> <div style='background-color: rgba(234.161826509, 123.464235406, 96.337450893, 1.0); color: rgba(10, 10, 10, 1.0); border-radius: 5px; padding: 2px; margin: 1px;font-weight: 800;width: fit-content; display: flex;'>care</div> <div style='background-color: rgba(179.94665529, 3.9668208, 38.30936706, 1.0); color: rgba(10, 10, 10, 1.0); border-radius: 5px; padding: 2px; margin: 1px;font-weight: 800;width: fit-content; display: flex;'>reform</div> <div style='background-color: rgba(214.034617907, 219.59754054200002, 228.09590967100002, 1.0); color: rgba(10, 10, 10, 1.0); border-radius: 5px; padding: 2px; margin: 1px;font-weight: 800;width: fit-content; display: flex;'>:</div> <div style='background-color: rgba(246.56513677499998, 166.252004514, 135.659264484, 1.0); color: rgba(10, 10, 10, 1.0); border-radius: 5px; padding: 2px; margin: 1px;font-weight: 800;width: fit-content; display: flex;'>progress</div> <div style='background-color: rgba(216.078050931, 219.930483006, 225.81281994300002, 1.0); color: rgba(10, 10, 10, 1.0); border-radius: 5px; padding: 2px; margin: 1px;font-weight: 800;width: fit-content; display: flex;'>to</div> <div style='background-color: rgba(231.069304179, 214.73322162, 205.568401236, 1.0); color: rgba(10, 10, 10, 1.0); border-radius: 5px; padding: 2px; margin: 1px;font-weight: 800;width: fit-content; display: flex;'>date</div> <div style='background-color: rgba(213.012901395, 219.43106931, 229.237454535, 1.0); color: rgba(10, 10, 10, 1.0); border-radius: 5px; padding: 2px; margin: 1px;font-weight: 800;width: fit-content; display: flex;'>and</div> <div style='background-color: rgba(241.112776222, 203.644463836, 184.391881411, 1.0); color: rgba(10, 10, 10, 1.0); border-radius: 5px; padding: 2px; margin: 1px;font-weight: 800;width: fit-content; display: flex;'>next</div> <div style='background-color: rgba(247.16858509499997, 174.670345506, 145.088708196, 1.0); color: rgba(10, 10, 10, 1.0); border-radius: 5px; padding: 2px; margin: 1px;font-weight: 800;width: fit-content; display: flex;'>steps</div> <div style='background-color: rgba(222.230590371, 219.888891726, 218.53914733500002, 1.0); color: rgba(10, 10, 10, 1.0); border-radius: 5px; padding: 2px; margin: 1px;font-weight: 800;width: fit-content; display: flex;'>"</div> <div style='background-color: rgba(215.05633441899997, 219.764011774, 226.95436480700002, 1.0); color: rgba(10, 10, 10, 1.0); border-radius: 5px; padding: 2px; margin: 1px;font-weight: 800;width: fit-content; display: flex;'>is</div> <div style='background-color: rgba(220.164916979, 220.596367934, 221.246640487, 1.0); color: rgba(10, 10, 10, 1.0); border-radius: 5px; padding: 2px; margin: 1px;font-weight: 800;width: fit-content; dis ...

# %%
def find_samples(dfc):
    df = dfc.copy()
    df["head_count"] = df["head_entity"].str.len()
    df = df.loc[df["head_count"] > 1, :]
    df = df[df["head_entity_names"].str.len() > 1]
    df["head_entity_shortest_name"] = df["head_entity_names"].apply(lambda x: min(x, key=len))
    df["different_name"] = df.apply(lambda row: not row["head_entity_shortest_name"] in row["head_entity_longest_name"], axis=1)
    df = df[df["different_name"]]
    df = df.drop_duplicates(["head_entity_longest_name"])
    df = df.sort_values("gold_doc_len").head(400).sample(50)
    return df[["head_entity_names"]]
    
find_samples(df)
# Out:
#                                       head_entity_names
# 1837   {Orange Business Services India, OBS, OBS India}
# 6400                             {Ajó, General Lavalle}
# 1280  {Zillebeke Churchyard Commonwealth War Graves ...
# 4857  {Home Edition, Extreme Makeover : Home Edition...
# 3687          {The Bee, The Sacramento Bee, Sacramento}
# 5047                 {Zevs, Christophe Aguirre Schwarz}
# 4531                             {Lisa Quenu, Macquart}
# 932                          {Upp Till Dig, The Seeker}
# 1661                   {Oscar Films, Venu Ravichandran}
# 3442               {AMR Corporation, American Airlines}
# 1326  {Bambi II, Bambi and the Great Prince of the F...
# 4037                       {Naval Canteen Service, NCS}
# 6563  {Suites for cello solo without bass, Suites à ...
# 4624  {Theobald Tiger, Kurt Tucholsky, Ignaz Wrobel,...
# 971   {GFSIS, Georgian Foundation for Strategic and ...
# 2289  {Hu language, Shanghai dialect, Hu dialect, Sh...
# 366   {Rav, GRaZ, Rabbenu HaZaken, Admor HaZaken, Sh...
# 5380                {Seyhun, Seyhoon, Houshang Seyhoun}
# 1478         {Fatima Jinnah Park, Bagh-e-Fatima Jinnah}
# 2310  {Fedor Ozep, Fyodor Otsep, Fyodor Aleksandrovi...
# 3215             {National Civil Aviation Agency, ANAC}
# 5310      {FiDi, Financial District of Lower Manhattan}
# 6475            {STES, seasonal thermal energy storage}
# 6859                        {Tyomnaya noch, Dark Night}
# 844                         {durga ooda, durga vaahini}
# 5020                  {National Turkey Federation, NTF}
# 2264           {Maclovius, Machutus, Maclou, Mac'h Low}
# 4265  {Humble Maria, Maria of the Slums, María la de...
# 5889                         {Lake Hiawatha, Rice Lake}
# 4352               {Wood - elves, Silvan, Silvan Elves}
# 5527                      {Snow Peak, Piton des Neiges}
# 864                          {Affordable Care Act, ACA}
# 632        {Mountain Areas Development Programme, MADA}
# 3666  {ELAM, Escuela Latinoamericana de Ciencias Méd...
# 5673       {Washington Place, William Washington House}
# 1734                       {Ooredoo, Ooredoo QSC, Qtel}
# 3962  {ENASA, Empresa Nacional de Autocamiones S.A.,...
# 421     {Jiang Caipin, Consort Jiang, Consort Mei, 江采蘋}
# 1424  {Jean de Croÿ, sire de Clery et de Boulainviller}
# 2183                            {Old Loggers Path, OLP}
# 6575  {Jang-e-Samugarh, Battle of Samugarh, The batt...
# 2065                 {Reddevitz Höft, Reddevitzer Höft}
# 6031      {Yasir al-Simli, Muhammaed Yasir Ahmed Taher}
# 3209                           {José María, José Maria}
# 6691      {Kungliga Hovkapellet, Royal Court Orchestra}
# 1727              {Sims - class, Sims class destroyers}
# 1628        {DBAP, Durham Bulls Athletic Park, D - Bap}
# 104                            {Medini Ray, Madini Rai}
# 3064  {Sticky Wicket Stadium, Stanford Cricket Groun...
# 4302  {Ernesto Alonso Vargas Contreras, D'Alessio, E...

# %%
df

# %%
df[df["query"].str.contains("uk")]
